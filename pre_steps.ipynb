# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from tqdm import tqdm
import shutil

# %%
# os.chdir('/content/drive/MyDrive/project')
# !git clone https://github.com/EgovisionPolito/mldl23-ego.git

# %% [markdown]
# # data

# %%
# os.chdir('/content/drive/MyDrive/DATA_p01_p08_p22/unzip_data')
# !unzip -q '/content/drive/MyDrive/DATA_p01_p08_p22/P08.zip'
# !unzip -q '/content/drive/MyDrive/DATA_p01_p08_p22/P22.zip'

# %%
# os.chdir('/content/drive/MyDrive/project')
# !mkdir -p ek_data/frames

# %%
# %%bash


# # Untar
# for file in /content/drive/MyDrive/DATA_p01_p08_p22/unzip_data/*.tar.gz; do
#   fn=$(basename $file)
#   fn=${fn/.tar.gz/}
#   ls -lah $file
#   mkdir -p ek_data/frames/$fn
#   tar xf $file --directory=ek_data/frames/$fn
# done

# %%
os.chdir('/content/drive/MyDrive/project/ek_data/frames')

# %%
# %%bash
#
#
# # Untar
# for file in /content/drive/MyDrive/shahin/P01/*.tar.gz; do
#   fn=$(basename $file)
#   fn=${fn/.tar.gz/}
#   ls -lah $file
#   mkdir -p ek_data/frames/$fn
#   tar xfk $file --directory=$fn
# done

# %%
# %%time
from IPython.display import Javascript
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))
os.chdir('/content/drive/MyDrive/project/ek_data/frames')
path1 = '/content/drive/MyDrive/project/ek_data/frames'
list_of_dir= os.listdir('/content/drive/MyDrive/project/ek_data/frames')
check = True
for folder in tqdm(list_of_dir):
  pth = os.path.join(path1, folder)
  files = os.listdir(pth)
  try:
    length = len(files)
    print('\n',folder ,length)
    print('path: ',pth)
    if length == 0:
      # shutil.rmtree(pth)
      tar_path = os.path.join('/content/drive/MyDrive/DATA_p01_p08_p22/unzip_data', folder+'.tar.gz')

      print('tar file : ',tar_path)
      # !tar xf $tar_path  --directory=$pth
      print('\n new size of path: ',len(os.listdir(pth)))
  except:
    print("!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
#   2%|▏         | 1/57 [00:00<00:49,  1.13it/s]
#  P01_01 64447
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_01
#   5%|▌         | 3/57 [00:01<00:20,  2.59it/s]
#  P01_02 24644
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_02
#
#  P01_03 4186
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_03
#
#  P01_04 4156
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_04
#   9%|▉         | 5/57 [00:01<00:16,  3.12it/s]
#  P01_05 29627
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_05
#  12%|█▏        | 7/57 [00:02<00:13,  3.71it/s]
#  P01_06 23571
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_06
#
#  P01_07 7031
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_07
#
#  P01_08 3752
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_08
#  16%|█▌        | 9/57 [00:04<00:24,  1.97it/s]
#  P01_09 89540
# path:  /content/drive/MyDrive/project/ek_data/frames/P01_09
#
#  P01_10 6130
# ...

# %%
# list_of_dir= os.listdir('/content/drive/MyDrive/project/ek_data/frames')
# for i in list_of_dir:
#  try:
#   os.remove(os.path.join('/content/drive/MyDrive/project/ek_data/frames', i))
#  except:
#   print(i)
# Out:
# P08_21
# P08_24
# P08_25
# P08_26
# P08_27
# P08_28
# P22_01
# P22_02
# P22_03
# P22_04
# P22_05
# P22_06
# P22_07
# P22_08
# P22_09
# P22_10
# P22_11
# P22_12
# P22_13
# P22_14
# P22_15
# P22_16
# P22_17
# P01_12
# P01_11
# P01_13
# P01_01
# P01_02
# P01_03
# P01_04
# P01_05
# P01_06
# P01_07
# P01_08
# P01_09
# P01_10
# P01_14
# P08_01
# P08_02
# P08_03
# P08_04
# P08_05
# P08_06
# P08_07
# P08_08
# P08_09
# P08_10
# P08_11
# P08_12
# P08_13
# P08_14
# P08_15
# P08_16
# P08_17
# P08_18
# P08_19
# P08_20
# P08_22

# %%
os.listdir('/content/drive/MyDrive/DATA_p01_p08_p22/unzip_data')
# Out:
# ['P01_01.tar.gz',
#  'P01_02.tar.gz',
#  'P01_03.tar.gz',
#  'P01_04.tar.gz',
#  'P01_05.tar.gz',
#  'P01_06.tar.gz',
#  'P01_07.tar.gz',
#  'P01_08.tar.gz',
#  'P01_09.tar.gz',
#  'P01_10.tar.gz',
#  'P01_11.tar.gz',
#  'P01_12.tar.gz',
#  'P01_13.tar.gz',
#  'P01_14.tar.gz',
#  'P01_15.tar.gz',
#  'P01_16.tar.gz',
#  'P01_17.tar.gz',
#  'P01_18.tar.gz',
#  'P01_19.tar.gz',
#  'P08_01.tar.gz',
#  'P08_02.tar.gz',
#  'P08_03.tar.gz',
#  'P08_04.tar.gz',
#  'P08_05.tar.gz',
#  'P08_07.tar.gz',
#  'P08_06.tar.gz',
#  'P08_08.tar.gz',
#  'P08_09.tar.gz',
#  'P08_10.tar.gz',
#  'P08_11.tar.gz',
#  'P08_12.tar.gz',
#  'P08_13.tar.gz',
#  'P08_14.tar.gz',
#  'P08_15.tar.gz',
#  'P08_16.tar.gz',
#  'P08_17.tar.gz',
#  'P08_18.tar.gz',
#  'P08_19.tar.gz',
#  'P08_20.tar.gz',
#  'P08_21.tar.gz',
#  'P08_22.tar.gz',
#  'P08_23.tar.gz',
#  'P08_24.tar.gz',
#  'P08_25.tar.gz',
#  'P08_26.tar.gz',
#  'P08_27.tar.gz',
#  'P08_28.tar.gz',
#  'P22_01.tar.gz',
#  'P22_02.tar.gz',
#  'P22_03.tar.gz',
# ...

# %%
# %cd /content/drive/MyDrive/DATA_p01_p08_p22/unzip_data
# Out:
# /content/drive/MyDrive/DATA_p01_p08_p22/unzip_data

# %%
# !ls
# Out:
# ek_data        P08_10.tar.gz  P08_20.tar.gz  P22_02.tar.gz  P22_12.tar.gz
# P08_01.tar.gz  P08_11.tar.gz  P08_21.tar.gz  P22_03.tar.gz  P22_13.tar.gz
# P08_02.tar.gz  P08_12.tar.gz  P08_22.tar.gz  P22_04.tar.gz  P22_14.tar.gz
# P08_03.tar.gz  P08_13.tar.gz  P08_23.tar.gz  P22_05.tar.gz  P22_15.tar.gz
# P08_04.tar.gz  P08_14.tar.gz  P08_24.tar.gz  P22_06.tar.gz  P22_16.tar.gz
# P08_05.tar.gz  P08_15.tar.gz  P08_25.tar.gz  P22_07.tar.gz  P22_17.tar.gz
# P08_06.tar.gz  P08_16.tar.gz  P08_26.tar.gz  P22_08.tar.gz
# P08_07.tar.gz  P08_17.tar.gz  P08_27.tar.gz  P22_09.tar.gz
# P08_08.tar.gz  P08_18.tar.gz  P08_28.tar.gz  P22_10.tar.gz
# P08_09.tar.gz  P08_19.tar.gz  P22_01.tar.gz  P22_11.tar.gz

# %% [markdown]
# # conda

# %%
os.chdir('/content/drive/MyDrive/project')

# %%
# Install conda on Google Colab

# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# Create a conda environment
# !conda env create --name egovision -f mldl23-ego/requirements.yaml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ...
# openssl-1.1.1q       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
# nest-asyncio-1.5.5   | 16 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# zipp-3.15.0          | 17 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pathspec-0.9.0       | 45 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# jupyter-1.0.0        | 7 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# nbclient-0.5.13      | 91 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# nb_conda_kernels-2.3 | 27 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# cryptography-37.0.1  | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# pytz-2022.1          | 196 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ## conda-pack

# %%
# !conda install conda-pack
# !conda install -c conda-forge conda-pack
# Pack environment my_env into my_env.tar.gz
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda-pack
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     conda-23.3.1               |  py310hff52083_0         941 KB  conda-forge
#     conda-pack-0.7.0           |     pyh6c4a22f_0          30 KB  conda-forge
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     openssl-3.1.0              |       hd590300_3         2.5 MB  conda-forge
#     packaging-23.1             |     pyhd8ed1ab_0          45 KB  conda-forge
# ...

# %%
! conda pack -n egovision



# # Pack environment located at an explicit path into my_env.tar.gz
# $ conda pack -p /explicit/path/to/my_env
